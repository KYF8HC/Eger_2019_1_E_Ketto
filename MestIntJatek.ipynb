# %% [markdown]
# <a href="https://colab.research.google.com/github/KYF8HC/Eger_2019_1_E_Ketto/blob/master/MestIntJatek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Jatek:
      def __init__(self):
        self.init_game()

      def init_game(self):
        self.current_state = [['.','.','.','.'],
                              ['.','.','.','.'],
                              ['.','.','.','.'],
                              ['.','.','.','.']]
                              
        self.player_turn = 'S'
        self.turn = 0
        self.current_phase = 1
      def draw_board(self):
          for i in range(0, 4):
              print(" | ", self.current_state[i][0], " | ", self.current_state[i][1] ," | ", self.current_state[i][2], " | ", self.current_state[i][3], " | " )
          print()

      def play(self):
          self.game_loop()

      def game_loop(self):
          self.init_game()
          while True:
            self.draw_board()
            self.result =  None
            if self.turn == 4:
              self.result = self.is_end_state()

            if self.result != None:
              if self.result == 'S':
                  print('The winner is S!')
              elif self.result == 'V':
                  print('The winner is V!')
              elif self.result == '.':
                  print("It's a tie!")
              return

            if self.is_board_full():
              self.current_phase = 2

            if self.current_phase == 1:
              if self.player_turn == 'S':

                  while True:
                      px = int(input('Insert the X coordinate: '))
                      py  = int(input('Insert the Y coordinate: '))

                      (qx, qy) = (px, py)

                      if self.is_valid_position(px, py):
                          self.current_state[px][py] = 'S'
                          self.player_turn = 'V'
                          break
                      else:
                          print('The move is not valid! Try again.')

              else:
                  #(m, px, py) = self.max()
                  #self.current_state[px][py] = 'V'
                  #self.player_turn = 'S'
                  temp=False
                  for i in range(4):
                    for j in range(4):
                      if self.is_valid_position(i, j):
                        self.current_state[i][j] = 'V'
                        self.player_turn = 'S'  
                        temp=True
                        break
                    if temp:
                      break                    
            if self.current_phase == 2:
              while True:
                if self.player_turn == 'S':
                  while True:                 
                    px = int(input('Insert the X coordinate: '))
                    py  = int(input('Insert the Y coordinate: '))
                    if self.current_state[px][py] == 'S':
                      self.current_state[px][py] = '.'
                      (qx, qy) = (px, py)

                      px = int(input('Insert the X coordinate: '))
                      py  = int(input('Insert the Y coordinate: '))

                      if not((px > qx + 1 or px < qx-1) or (py > qy + 1 or py < qy-1)):            
                        if(px == qx + 1):
                          if(qx == 0):
                            if self.current_state[px][py] == '.':
                              self.current_state[px][py] = 'S'
                            else:
                              self.current_state[px+2][py] = self.current_state[px+1][py]
                              self.current_state[px+1][py] = self.current_state[px][py]
                              self.current_state[px][py] = 'S'
                          if(qx == 1):
                            if self.current_state[px][py] == '.':
                              self.current_state[px][py] = 'S'
                            else:
                              self.current_state[px+1][py] = self.current_state[px][py]
                              self.current_state[px][py] = 'S'
                          if(qx == 2):
                            self.current_state[px][py] = 'S'
                        if(px == qx - 1):
                          if(qx == 3):
                            if self.current_state[px][py] == '.':
                              self.current_state[px][py] = 'S'
                            else:
                              self.current_state[px-2][py] = self.current_state[px-1][py]
                              self.current_state[px-1][py] = self.current_state[px][py]
                              self.current_state[px][py] = 'S'
                          if(qx == 2):
                            if self.current_state[px][py] == '.':
                              self.current_state[px][py] = 'S'
                            else:
                              self.current_state[px-1][py] = self.current_state[px][py]
                              self.current_state[px][py] = 'S'
                          if(qx == 1):
                            self.current_state[px][py] = 'S'
                        if(py == qy + 1):
                          if(qy == 0):
                            if self.current_state[px][py] == '.':
                              self.current_state[px][py] = 'S'
                            else:
                              self.current_state[px][py+2] = self.current_state[px][py+1]
                              self.current_state[px][py+1] = self.current_state[px][py]
                              self.current_state[px][py] = 'S'
                          if(qy == 1):
                            if self.current_state[px][py] == '.':
                              self.current_state[px][py] = 'S'
                            else:
                              self.current_state[px+1][py] = self.current_state[px][py]
                              self.current_state[px][py] = 'S'
                          if(qy == 2):
                            self.current_state[px][py] = 'S'
                        if(py == qy - 1):
                          if(qy == 3):
                            if self.current_state[px][py] == '.':
                              self.current_state[px][py] = 'S'
                            else:
                              self.current_state[px][py-2] = self.current_state[px][py-1]
                              self.current_state[px][py-1] = self.current_state[px][py]
                              self.current_state[px][py] = 'S'
                          if(qy == 2):
                            if self.current_state[px][py] == '.':
                              self.current_state[px][py] = 'S'
                            else:
                              self.current_state[px-1][py] = self.current_state[px][py]
                              self.current_state[px][py] = 'S'
                          if(qy == 1):
                            self.current_state[px][py] = 'S'
                        self.draw_board()
                        self.player_turn = 'V'
                        break
                      else:
                        print('The move is not valid! Try again.')
                    else:
                      print('The move is not valid! Try again.')
                else:
                 if self.player_turn == 'V':
                  temp=False
                  (qx,qy) =(0,0)
                  for i in range(4):
                    for j in range(4):
                      if self.current_state[i][j] == 'V':
                        self.draw_board()
                        (qx, qy) = (i, j)
                        if i == 0:
                          self.current_state[i+3][j] = self.current_state[i+2][j]
                          self.current_state[i+2][j] = self.current_state[i+1][j]
                          self.current_state[i+1][j] = self.current_state[i][j]
                          self.current_state[i][j] = '.'
                          break
                        elif i == 1:
                          self.current_state[i+2][j] = self.current_state[i+1][j]
                          self.current_state[i+1][j] = self.current_state[i][j]
                          self.current_state[i][j] = '.'
                          break
                        elif i == 2:
                          self.current_state[i+1][j] = self.current_state[i][j]
                          self.current_state[i][j] = '.'
                          break
                        self.player_turn = 'S'  
                        temp=True
                        break
                      break
                    if temp:
                      break                  

      def is_valid_position(self, px, py):
        if (px<0 or px>3) and (py<0 or py>3):
            return False
        elif self.current_state[px][py] == '.':
            return True
        else:
            return False

      def is_end_state(self):
        sumS= 0
        sumV = 0
        for i in range(4):
          for j in range(4):
            if self.current_state[i][j] == 'S':
              sumS += 1
            elif self.current_state[i][j] == 'V':
              sumV += 1
        if sumS < sumV: 
          return('V')
        elif sumS > sumV: 
          return ('S')
      
      def is_board_full(self):
        for i in range(4):
          for j in range(4):
            if self.current_state[i][j] is '.':
              return (False)
        return (True)


      def max(self):
        value = -2

        px = None
        py = None

        result = self.is_end_state()     
        if result == 'S':
            return (-1, 0, 0)
        elif result == 'V':
            return (1, 0, 0)
        elif result == '.':
            return (0, 0, 0)
        if self.current_phase == 1:
          for i in range(0, 4):
              for j in range(0, 4):
                  if self.current_state[i][j] == '.':
                    self.current_state[i][j]='V'
                    (min, min_x, min_y)=self.min()
                    if(min > value):
                      value=min
                      px =i
                      py =j
                    self.current_state[i][j] = '.'
          return (value, px, py)

      def min(self):
        value = 2

        qx = None
        qy = None

        result = self.is_end_state()
        if result == 'S':
            return (-1, 0, 0)
        elif result == 'V':
            return (1, 0, 0)
        elif result == '.':
            return (0, 0, 0)
        if self.current_phase == 1:
          for i in range(0, 4):
              for j in range(0, 4):
                  if self.current_state[i][j] == '.':
                    self.current_state[i][j]= 'S'
                    (max, qx, qy) = self.max()
                    if (max < value):
                      value=max
                      qx=i
                      qy=j
                    self.current_state[i][j]= '.'
          return (value, qx, qy)

# %%
game = Jatek()
game.play()
# Out:
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#
# Insert the X coordinate: 0
# Insert the Y coordinate: 0
#  |  S  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#
#  |  S  |  V  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#
# Insert the X coordinate: 0
# Insert the Y coordinate: 2
#  |  S  |  V  |  S  |  .  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#
#  |  S  |  V  |  S  |  V  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#
# Insert the X coordinate: 1
# Insert the Y coordinate: 1
#  |  S  |  V  |  S  |  V  |
#  |  .  |  S  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#
#  |  S  |  V  |  S  |  V  |
#  |  V  |  S  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#  |  .  |  .  |  .  |  .  |
#
# ...
